# %% [markdown]
# # Car Price Prediction
#
# ### Problem Statement
# Analyse the Car Dataset and perform various operations. Also Try to understand the relationship of different independent variables with our target variable.
#
# 1. Data Cleaning
# 2. Exploratory Data Analysis
# 3. Feature extraction and selection
# 4. Data Modelling and evaluation

# %%
# Import the required Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# ## 1. Data Cleaning

# %%
# Read the Dataset
data = pd.read_csv('CarPrice_Assignment.csv')
data.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %% [markdown]
# **Lets see the shape and description of our Dataset**

# %%
data.shape
# Out:
# (205, 26)

# %% [markdown]
# There are 26 Columns and 205 Rows

# %%
data.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %% [markdown]
# So there are 16 Numerical Columns and,
# 10 Categorical Columns

# %%
data.isna().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %% [markdown]
# There are no null values in our data

# %% [markdown]
# After some googling we can say that `Symboling` is a categorical column.
#
# SO we have to change the datatype of `Symboling`
#
# * Symboling - Cars are initially assigned a risk factor symbol associated with its price.
#
# +3 = risky and -3 = safe

# %%
data.symboling.unique()
# Out:
# array([ 3,  1,  2,  0, -1, -2], dtype=int64)

# %%
data['symboling']=data['symboling'].astype('str')

# %% [markdown]
# Now lets Drop the unwanted Column
#
# as we know ID will not play any role in Car Price Prediction, so we will drop it

# %%
data = data.drop('car_ID',axis=1)

# %%
data.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
data.CarName
# Out:
# 0            alfa-romero giulia
# 1           alfa-romero stelvio
# 2      alfa-romero Quadrifoglio
# 3                   audi 100 ls
# 4                    audi 100ls
#                  ...
# 200             volvo 145e (sw)
# 201                 volvo 144ea
# 202                 volvo 244dl
# 203                   volvo 246
# 204                 volvo 264gl
# Name: CarName, Length: 205, dtype: object

# %% [markdown]
# Now we can see that `CarName` column contain the model of the car which will be not so usefull for us, so lets extract the Car Company Name from `CarName`
#
# * Extracting Car Company Name from CarName Column

# %%
Company = data.CarName.apply(lambda x: x.split(" ")[0])
data.insert(3, "Company", Company)

# Droping the old CarName Column
data.drop("CarName",axis=1,inplace=True)

data.head()
# Out:
#   symboling fueltype      Company aspiration doornumber      carbody  \
# 0         3      gas  alfa-romero        std        two  convertible
# 1         3      gas  alfa-romero        std        two  convertible
# 2         1      gas  alfa-romero        std        two    hatchback
# 3         2      gas         audi        std       four        sedan
# 4         2      gas         audi        std       four        sedan
#
#   drivewheel enginelocation  wheelbase  carlength  ...  enginesize  \
# 0        rwd          front       88.6      168.8  ...         130
# 1        rwd          front       88.6      168.8  ...         130
# 2        rwd          front       94.5      171.2  ...         152
# 3        fwd          front       99.8      176.6  ...         109
# 4        4wd          front       99.4      176.6  ...         136
#
#    fuelsystem  boreratio stroke compressionratio  horsepower peakrpm  citympg  \
# ...

# %%
data['Company'] = data.Company.str.lower()
data.Company.unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'maxda', 'mazda', 'buick', 'mercury',
#        'mitsubishi', 'nissan', 'peugeot', 'plymouth', 'porsche',
#        'porcshce', 'renault', 'saab', 'subaru', 'toyota', 'toyouta',
#        'vokswagen', 'volkswagen', 'vw', 'volvo'], dtype=object)

# %% [markdown]
# As we can see there are lot of duplicate car company names with just different spelling
#
# 1. toyota and toyouta
# 2. mazda and maxda
# 3. porcshce and porsche
# 4. vokswagen , volkswagen and vw
#
# Lets replace them

# %%
data['Company'] = data['Company'].replace({'maxda': 'mazda', 
                                           'porcshce': 'porsche', 
                                           'toyouta': 'toyota', 
                                           'vokswagen': 'volkswagen', 
                                           'vw': 'volkswagen'})

# %%
data['Company'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'buick', 'mercury', 'mitsubishi',
#        'nissan', 'peugeot', 'plymouth', 'porsche', 'renault', 'saab',
#        'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
#Checking for duplicates
data.loc[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [symboling, fueltype, Company, aspiration, doornumber, carbody, drivewheel, enginelocation, wheelbase, carlength, carwidth, carheight, curbweight, enginetype, cylindernumber, enginesize, fuelsystem, boreratio, stroke, compressionratio, horsepower, peakrpm, citympg, highwaympg, price]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# There are no Duplicate Values

# %% [markdown]
# **Lets categories the columns in categorical and numerical columns**

# %%
# Categorical Columns

categorical_cols = data.select_dtypes(include='object').columns
categorical_cols
# Out:
# Index(['symboling', 'fueltype', 'Company', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'enginetype',
#        'cylindernumber', 'fuelsystem'],
#       dtype='object')

# %%
# Numerical Columns

numerical_cols = data.select_dtypes(exclude='object').columns
numerical_cols
# Out:
# Index(['wheelbase', 'carlength', 'carwidth', 'carheight', 'curbweight',
#        'enginesize', 'boreratio', 'stroke', 'compressionratio', 'horsepower',
#        'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
print("Total Numerical Cols = ", len(numerical_cols))
print("Total Categorical Cols = ", len(categorical_cols))
# Out:
# Total Numerical Cols =  14
# Total Categorical Cols =  11

# %% [markdown]
# **So Now, there are 14 Numerical Columns and, 11 Categorical Columns**

# %% [markdown]
# ## 2. EDA (Exploratory Data Analysis)

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# **Lets Check the Distribution of our Target Columns i.e `Price`**

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)
plt.title('Car Price Distribution Plot')
sns.distplot(data.price)

plt.subplot(1,2,2)
plt.title('Car Price Spread')
sns.boxplot(y=data.price)

plt.show()

# %%
print(data.price.describe(percentiles = [0.25,0.50,0.75,0.85,0.90,1]))
# Out:
# count      205.000000
# mean     13276.710571
# std       7988.852332
# min       5118.000000
# 25%       7788.000000
# 50%      10295.000000
# 75%      16503.000000
# 85%      18500.000000
# 90%      22563.000000
# 100%     45400.000000
# max      45400.000000
# Name: price, dtype: float64

# %% [markdown]
# 1. `Price` is Right skewed, means the most price are below 15000.
# 2. Also we by seeing the Box Plot can say that there are outliers in `Price`
# 3. The data points are far spread out from the mean, which indicates a high variance in the car prices.(85% of the prices are below 18,500, whereas the remaining 15% are between 18,500 and 45,400.)

# %%
# Visualise different car company

sns.countplot(data = data
            ,y = 'Company',
            order = data['Company'].value_counts().index
            );

# %% [markdown]
# So from above visulization we can say that,
#
# 1. Toyoto is the most buyed car
# 2. Mercury is the least buyed car

# %%
# pie chart to show the distribution of fueltype

plt.figure(figsize=(3,3))
plt.pie(x=data.fueltype.value_counts(),
        labels=data.fueltype.value_counts().index,
        autopct='%1.1f%%')
plt.legend(title="Fuel Type")
plt.show()

# %% [markdown]
# **By Above plot we can say that most car use Gas as Fuel**

# %%
numerical_cols
# Out:
# Index(['wheelbase', 'carlength', 'carwidth', 'carheight', 'curbweight',
#        'enginesize', 'boreratio', 'stroke', 'compressionratio', 'horsepower',
#        'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
# Visualising Numerical Data

def num_analysis(a):
  fig = plt.figure(figsize=(10,3))
  s1=fig.add_subplot(1,2,1)
  s2=fig.add_subplot(1,2,2)

  sns.distplot(data[a], ax=s1)
  
  fig.suptitle(a, fontsize=16)

  sns.boxplot(y=data[a])
  plt.show()

for columns in numerical_cols:
  num_analysis(columns)

# %%
categorical_cols
# Out:
# Index(['symboling', 'fueltype', 'Company', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'enginetype',
#        'cylindernumber', 'fuelsystem'],
#       dtype='object')

# %%
# Visualising Categorical Data

def cat_analysis(col,fig):
    plt.subplot(4,3,fig)
    sns.countplot(data = data,
                  y = col,
                  order = data[col].value_counts().index,
                  palette=("cubehelix"))
    plt.title(col)

plt.figure(figsize=(16,20))

n = 1
for cols in categorical_cols:
  cat_analysis(cols,n)
  n += 1

plt.tight_layout()

# %% [markdown]
# By above visualization we can say that:
# 1. It seems that the cars with symboling with 0 and 1 values are most sold.
# 2. Toyoto is the most prefered car company and Mercury is least.
# 3. Gas is the most prefered fuel type
# 4. 115 cars has four dooors and 90 cars has 2 doors.
# 5. Sedan is top Car type prefered
# 6. FWD Drive wheel cars are prefered
# 7. Cars with Front Engine location is prefered
# 8. Ohc is prefered engine type
# 9. A four cylinder car is prefered most
# 10. Most number of cars having fuel system mpfi and least number of cars having fuel system mfi and spfi

# %% [markdown]
# ### Bivariate Analysis

# %%
numerical_cols
# Out:
# Index(['wheelbase', 'carlength', 'carwidth', 'carheight', 'curbweight',
#        'enginesize', 'boreratio', 'stroke', 'compressionratio', 'horsepower',
#        'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
len(numerical_cols[:-1])
# Out:
# 13

# %%
# Visualizing Numerical Columns with Price

def num_bianalysis(col,fig):
    plt.subplot(5,3,fig)
    sns.regplot(x=col, y="price", 
                data=data,color='g', 
                line_kws={"color": "red"})
    plt.title(col)

plt.figure(figsize=(15,20))

n = 1
for cols in numerical_cols:
  num_bianalysis(cols,n)
  n += 1

plt.tight_layout()

# %% [markdown]
# 1. `carwidth`, `carlength`, `curbweight`, `enginesize`, `boreratio`, `horsepower` and `wheelbase` - have a poitive correlation with price.
# 2. `citympg` and `highwaympg` - have a negative correlation with price.
# 3. `carheight`, `peakrpm`, `compressionratio` and `stroke` - doesn't have correlation with price.

# %%
categorical_cols
# Out:
# Index(['symboling', 'fueltype', 'Company', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'enginetype',
#        'cylindernumber', 'fuelsystem'],
#       dtype='object')

# %%
# Visualising Categorical Data with Price

def cat_bianalysis(a):
  fig = plt.figure(figsize=(10,5))
  s1=fig.add_subplot(1,2,1)
  s2=fig.add_subplot(1,2,2)

  df = pd.DataFrame(data.groupby([a])['price'].mean().sort_values(ascending = False))
  df.plot(kind='bar',ax=s1, color="#7eb54e")
  
  # fig.suptitle(a)

  sns.boxplot(x=data[a], y=data.price, palette=("PuBuGn"))
  plt.xticks(rotation=90)
  plt.tight_layout()
  plt.show()


for columns in categorical_cols:
  cat_bianalysis(columns)

# %% [markdown]
# By above visualisation:
# 1. The cars with -1 symboling seems to be high priced (as it makes sense too, insurance risk rating -1 is quite good). But it seems that symboling with 3 value has the price range similar to -2 value. There is a dip in price at symboling 1.
# 2. Jaguar and Buick have highest average price.
# 3. Diseal type Vehicle are Costly that gas type.
# 4. Turbo have higher price range than the std
# 5. Door Number is not affacting the price much. There is no sugnificant difference between the categories
# 6. Hardtop and Convertible vehicles are more costlier than others.
# 7. Real Wheel Drive cars are costly as compared to 4wd and fwd
# 8. Cars with engine in rear are more than double the average cost of cars with engine in front.
# 9. ohcv engine type has the highest price range
# 10. eight and twelve cylinder cars are the costliest
# 11. mpfi and idi having the highest price range.

# %% [markdown]
# ## 3. Feature Extraction and Selection

# %% [markdown]
# **Deriving new features**

# %%
#Fuel economy
data['fueleconomy'] = (0.55 * data['citympg']) + (0.45 * data['highwaympg'])

# %%
plt.figure(figsize=(8,6))

plt.title('Fuel economy vs Price')
sns.regplot(x=data['fueleconomy'],
            y=data['price'],
           line_kws={"color": "red"})
plt.xlabel('Fuel Economy')
plt.ylabel('Price')

plt.show()
plt.tight_layout()

# %% [markdown]
# `fueleconomy` has negative correlation with `price`.

# %%
# encoding ordinal categorical columns

data['doornumber'] = data['doornumber'].map({'two': 2, 'four': 4})
data['cylindernumber'] = data['cylindernumber'].map({'two': 2, 'three': 3, 
                                                     'four': 4, 'five': 5, 
                                                     'six': 6, 'eight': 8, 
                                                     'twelve': 12})
data.head()
# Out:
#   symboling fueltype      Company aspiration  doornumber      carbody  \
# 0         3      gas  alfa-romero        std           2  convertible
# 1         3      gas  alfa-romero        std           2  convertible
# 2         1      gas  alfa-romero        std           2    hatchback
# 3         2      gas         audi        std           4        sedan
# 4         2      gas         audi        std           4        sedan
#
#   drivewheel enginelocation  wheelbase  carlength  ...  fuelsystem  boreratio  \
# 0        rwd          front       88.6      168.8  ...        mpfi       3.47
# 1        rwd          front       88.6      168.8  ...        mpfi       3.47
# 2        rwd          front       94.5      171.2  ...        mpfi       2.68
# 3        fwd          front       99.8      176.6  ...        mpfi       3.19
# 4        4wd          front       99.4      176.6  ...        mpfi       3.19
#
# ...

# %%
data_new = data.drop(['citympg','highwaympg'],axis=1)
data_new['symboling']=data_new['symboling'].astype('int64')
data_new.head()
# Out:
#    symboling fueltype      Company aspiration  doornumber      carbody  \
# 0          3      gas  alfa-romero        std           2  convertible
# 1          3      gas  alfa-romero        std           2  convertible
# 2          1      gas  alfa-romero        std           2    hatchback
# 3          2      gas         audi        std           4        sedan
# 4          2      gas         audi        std           4        sedan
#
#   drivewheel enginelocation  wheelbase  carlength  ...  cylindernumber  \
# 0        rwd          front       88.6      168.8  ...               4
# 1        rwd          front       88.6      168.8  ...               4
# 2        rwd          front       94.5      171.2  ...               6
# 3        fwd          front       99.8      176.6  ...               4
# 4        4wd          front       99.4      176.6  ...               5
#
#    enginesize  fuelsystem boreratio  stroke  compressionratio horsepower  \
# ...

# %%
# !pip install dython

# %%
# finding correlation of numerical and categorical features

from dython.nominal import associations

associations(data_new, figsize = (18, 18))
plt.show()

# %% [markdown]
# From above Matrix:
# 1. Fueltype have a high postive correlation with Fuel Systema and Compression Ratio
# 2. Company is highly correlated with multiple columns.
# 3. carlength and carwidth and curbweight and wheelbase are highly positive correlated.
# 4. cylinder number is positively correlated with enginesize.
# 5. fuelsystem and compressionratio is very highly positive correlated.

# %%
#It will only plot numerical columns

# # Correlation Matrix
# plt.figure(figsize=(30,25)) 
# sns.heatmap(data_new.corr(), 
#             annot=True,
#            cmap="crest")

# %% [markdown]
# ### Recursive feature elimination (RFE) with random forest

# %%
# data_new.to_csv(r'C:Data.csv', index=False)

# %%
from sklearn import preprocessing
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import LabelEncoder

# %%
X = data_new.apply(lambda col: preprocessing.LabelEncoder().fit_transform(col))
X=X.drop(['Company','price'],axis=1)
y=data_new['price']

# %%
# Create the RFE object and rank each pixel
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import RFE
clf_rf_3 = RandomForestRegressor()      
rfe = RFE(estimator=clf_rf_3, n_features_to_select=16, step=1)
rfe = rfe.fit(X, y)
print('Chosen best 16 feature by rfe:',X.columns[rfe.support_])
# Out:
# Chosen best 16 feature by rfe: Index(['carbody', 'wheelbase', 'carlength', 'carwidth', 'carheight',
#        'curbweight', 'enginetype', 'cylindernumber', 'enginesize',
#        'fuelsystem', 'boreratio', 'stroke', 'compressionratio', 'horsepower',
#        'peakrpm', 'fueleconomy'],
#       dtype='object')

# %% [markdown]
# **After checking with different numbers we got a decent accuracy with Top 16 Features**

# %%
features=list(X.columns[rfe.support_])
features
# Out:
# ['carbody',
#  'wheelbase',
#  'carlength',
#  'carwidth',
#  'carheight',
#  'curbweight',
#  'enginetype',
#  'cylindernumber',
#  'enginesize',
#  'fuelsystem',
#  'boreratio',
#  'stroke',
#  'compressionratio',
#  'horsepower',
#  'peakrpm',
#  'fueleconomy']

# %% [markdown]
# SO these are the top Best 16 Features that we will use in modeling

# %%
data_new.head()
# Out:
#    symboling fueltype      Company aspiration  doornumber      carbody  \
# 0          3      gas  alfa-romero        std           2  convertible
# 1          3      gas  alfa-romero        std           2  convertible
# 2          1      gas  alfa-romero        std           2    hatchback
# 3          2      gas         audi        std           4        sedan
# 4          2      gas         audi        std           4        sedan
#
#   drivewheel enginelocation  wheelbase  carlength  ...  cylindernumber  \
# 0        rwd          front       88.6      168.8  ...               4
# 1        rwd          front       88.6      168.8  ...               4
# 2        rwd          front       94.5      171.2  ...               6
# 3        fwd          front       99.8      176.6  ...               4
# 4        4wd          front       99.4      176.6  ...               5
#
#    enginesize  fuelsystem boreratio  stroke  compressionratio horsepower  \
# ...

# %%
# Lets create a new Dataframe with Our best Independent Features and Target Varibale
df = data_new[features]
df['price'] = data_new['price']
df
# Out:
#          carbody  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0    convertible       88.6      168.8      64.1       48.8        2548
# 1    convertible       88.6      168.8      64.1       48.8        2548
# 2      hatchback       94.5      171.2      65.5       52.4        2823
# 3          sedan       99.8      176.6      66.2       54.3        2337
# 4          sedan       99.4      176.6      66.4       54.3        2824
# ..           ...        ...        ...       ...        ...         ...
# 200        sedan      109.1      188.8      68.9       55.5        2952
# 201        sedan      109.1      188.8      68.8       55.5        3049
# 202        sedan      109.1      188.8      68.9       55.5        3012
# 203        sedan      109.1      188.8      68.9       55.5        3217
# 204        sedan      109.1      188.8      68.9       55.5        3062
#
#     enginetype  cylindernumber  enginesize fuelsystem  boreratio  stroke  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   carbody           205 non-null    object
#  1   wheelbase         205 non-null    float64
#  2   carlength         205 non-null    float64
#  3   carwidth          205 non-null    float64
#  4   carheight         205 non-null    float64
#  5   curbweight        205 non-null    int64
#  6   enginetype        205 non-null    object
#  7   cylindernumber    205 non-null    int64
#  8   enginesize        205 non-null    int64
#  9   fuelsystem        205 non-null    object
#  10  boreratio         205 non-null    float64
#  11  stroke            205 non-null    float64
#  12  compressionratio  205 non-null    float64
#  13  horsepower        205 non-null    int64
#  14  peakrpm           205 non-null    int64
#  15  fueleconomy       205 non-null    float64
# ...

# %%
# Lets categories the columns in categorical and numerical columns

cat_cols = df.select_dtypes(include='object').columns
num_cols = df.select_dtypes(exclude='object').columns

# %%
cat_cols
# Out:
# Index(['carbody', 'enginetype', 'fuelsystem'], dtype='object')

# %% [markdown]
# ### Dummy Variables

# %%
df = pd.get_dummies(df, drop_first = True)
df.head()
# Out:
#    wheelbase  carlength  carwidth  carheight  curbweight  cylindernumber  \
# 0       88.6      168.8      64.1       48.8        2548               4
# 1       88.6      168.8      64.1       48.8        2548               4
# 2       94.5      171.2      65.5       52.4        2823               6
# 3       99.8      176.6      66.2       54.3        2337               4
# 4       99.4      176.6      66.4       54.3        2824               5
#
#    enginesize  boreratio  stroke  compressionratio  ...  enginetype_ohcf  \
# 0         130       3.47    2.68               9.0  ...                0
# 1         130       3.47    2.68               9.0  ...                0
# 2         152       2.68    3.47               9.0  ...                0
# 3         109       3.19    3.40              10.0  ...                0
# 4         136       3.19    3.40               8.0  ...                0
#
#    enginetype_ohcv  enginetype_rotor  fuelsystem_2bbl  fuelsystem_4bbl  \
# ...

# %%
# Split our data into X and Y

X = df.drop('price',axis=1)
y = df.price

# %%
### Train-Test Split

from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(X, y,
                                                 test_size=0.33, 
                                                 random_state = 45)

# %%
x_train.head()
# Out:
#      wheelbase  carlength  carwidth  carheight  curbweight  cylindernumber  \
# 165       94.5      168.7      64.0       52.6        2265               4
# 34        93.7      150.0      64.0       52.6        1956               4
# 117      108.0      186.7      68.3       56.0        3130               4
# 97        94.5      170.2      63.8       53.5        2037               4
# 197      104.3      188.8      67.2       57.5        3042               4
#
#      enginesize  boreratio  stroke  compressionratio  ...  enginetype_ohcf  \
# 165          98       3.24    3.08               9.4  ...                0
# 34           92       2.91    3.41               9.2  ...                0
# 117         134       3.61    3.21               7.0  ...                0
# 97           97       3.15    3.29               9.4  ...                0
# 197         141       3.78    3.15               9.5  ...                0
#
# ...

# %% [markdown]
# ## Modeling and Evaluation

# %% [markdown]
# ### Linear Regerssion

# %%
from sklearn.linear_model import LinearRegression

lreg = LinearRegression()
lreg.fit(x_train,y_train)
y_train_pred = lreg.predict(x_train)
y_test_pred = lreg.predict(x_test)
lreg.score(x_test,y_test)
# Out:
# 0.8685959658871

# %% [markdown]
# ### Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

dt_regressor = DecisionTreeRegressor(random_state=0)
dt_regressor.fit(x_train,y_train)
y_train_pred = dt_regressor.predict(x_train)
y_test_pred = dt_regressor.predict(x_test)
dt_regressor.score(x_test,y_test)
# Out:
# 0.8229168480553088

# %% [markdown]
# ### Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

Rf = RandomForestRegressor(n_estimators = 15,
                              criterion = 'mse',
                              random_state = 20,
                              n_jobs = -1)
Rf.fit(x_train,y_train)
Rf_train_pred = Rf.predict(x_train)
Rf_test_pred = Rf.predict(x_test)


Rf.score(x_test, y_test)
# Out:
# 0.8983443056118954

# %% [markdown]
# ### Conclusion
# **Random forest performing best (with accuracy ~ 0.90)**
